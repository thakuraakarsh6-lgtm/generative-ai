# %%
#flooting p0int number--presence of decimcal

# %%
z=3+4j
type(z)
# Out:
# complex

# %%
x="solan"
type(x)
# Out:
# str

# %% [markdown]
# a="true"
# type(a)

# %%
#none--define the null value means nothing
e=None
type(e)
# Out:
# NoneType
