# %%
my_sub="GenerativeAI"
print(my_sub)
# Out:
# GenerativeAI

# %%
 #triple qotues
 my_sentence='''this is a sentencesdfghjdfghjdfghjdfghj'''
# Out:
#   File "/tmp/ipython-input-3140615583.py", line 2
#     my_sentence='''this is a sentencesdfghjdfghjdfghjdfghj
#                 ^
# SyntaxError: incomplete input

# %%
my_sentence='''this is sentences with multiple lines'''

# %%
my_sub="machine learning"
len(my_sub)
# Out:
# 16

# %%
my_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1792447805.py in <cell line: 0>()
# ----> 1 my_
#
# NameError: name 'my_' is not defined

# %%
my_sub[0]
# Out:
# 'm'

# %%
my_sub="machine learning"
my_sub
# Out:
# 'machine learning'

# %%
my_sub[-16]
# Out:
# 'm'
